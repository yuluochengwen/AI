# %% [markdown]
# # GitHub 宠物病症患病处图片相关仓库/数据集检索报告
#
# 使用 GitHub Search API 对宠物（猫、狗等）病症患病处图片相关的仓库和数据集进行检索，整理如下。

# %% [markdown]
# ## 检索关键词
#
# - `cat dog skin disease`
# - `dog skin disease recognition`
# - `animal skin disease classification`
# - `pet disease detection CNN image`
# - `dog skin fungal bacterial infection dataset`
# - `DermaVet animal skin disease`

# %% [markdown]
# ## 检索结果汇总
#
# ### 1. AI-Models-Training-Cat-and-Dog-Skin-Disease-Medical-Datasets
# - **仓库地址**：https://github.com/QQ767172261/AI-Models-Training-Cat-and-Dog-Skin-Disease-Medical-Datasets-Training-AI-Models-for-Cat-and-Dog-Skin
# - **描述**：AI模型训练 猫狗皮肤病医疗数据集，用于训练猫狗皮肤病诊断的AI模型。
# - **语言**：未标注
# - **更新时间**：2025-11-26
#
# ---
#
# ### 2. FurSight_C — Cat & Dog Skin Disease Detection
# - **仓库地址**：https://github.com/Myriam2907/FurSight_C
# - **描述**：AI-powered Cat & Dog Skin Disease Detection using CNN + GNN。使用 CNN 和 GNN 对猫狗皮肤病进行检测。
# - **语言**：Python
# - **更新时间**：2025-10-01
#
# ---
#
# ### 3. Dog_Skin_Disease_Recognition
# - **仓库地址**：https://github.com/deb2025/Dog_Skin_Disease_Recognition
# - **描述**：上传狗狗皮肤区域的图片，系统自动分析并检测病症迹象。
# - **语言**：Jupyter Notebook
# - **Fork 数**：1
# - **更新时间**：2024-11-05
#
# ---
#
# ### 4. FURCAST_CARE_Animal-Skin-Disease-Prediction
# - **仓库地址**：https://github.com/Kaviyasri05/FURCAST_CARE_Animal-Skin-Disease-Prediction
# - **描述**：基于机器学习的动物皮肤病预测模型（Python），当前支持识别狗的皮肤真菌感染、细菌感染及正常三类。
# - **语言**：未标注
# - **更新时间**：2025-05-31
#
# ---
#
# ### 5. DermaVet-AI
# - **仓库地址**：https://github.com/Deadpool4138/DermaVet-AI
# - **描述**：Image classification for animal skin diseases（动物皮肤病图片分类）。
# - **语言**：未标注
# - **更新时间**：2025-05-18
#
# ---
#
# ### 6. Dog-Disease-Detection-Dataset
# - **仓库地址**：https://github.com/cryptic0053/Dog-Disease-Detection-Dataset
# - **描述**：犬类疾病检测数据集，基于 Jupyter Notebook。
# - **语言**：Jupyter Notebook
# - **更新时间**：2025-07-03
#
# ---
#
# ### 7. AI-LLM-Based-Disease-Detection-for-Cows
# - **仓库地址**：https://github.com/Abdo965/AI-LLM-Based-Disease-Detection-for-Cows
# - **描述**：利用大语言模型（LLM）和深度学习对牛的皮肤病（结节性皮肤病、乳腺炎）进行早期检测，支持上传图片并自动生成兽医健康报告。
# - **语言**：Python
# - **⭐ Star 数**：2
# - **更新时间**：2025-10-22

# %% [markdown]
# ## 补充：可参考的公开数据集平台
#
# GitHub 上专门的宠物病症患病处图片数据集仓库数量有限，建议同时参考以下平台获取更丰富的数据集：
#
# | 平台 | 关键词建议 | 链接 |
# |------|-----------|------|
# | Kaggle | `dog skin disease`, `cat disease`, `pet skin lesion` | https://www.kaggle.com/datasets |
# | Roboflow Universe | `dog disease`, `animal skin disease` | https://universe.roboflow.com |
# | Hugging Face Datasets | `pet disease`, `veterinary` | https://huggingface.co/datasets |
# | IEEE DataPort | `animal skin disease images` | https://ieee-dataport.org |

# %% [markdown]
# ## 结论
#
# GitHub 上**存在**若干宠物（主要为猫狗）皮肤病/病症图片相关的仓库，最相关的有：
#
# 1. **猫狗皮肤病医疗数据集**（含 AI 模型训练）：`QQ767172261/AI-Models-Training-Cat-and-Dog-Skin-Disease-Medical-Datasets-...`
# 2. **狗皮肤病识别**（含 Jupyter Notebook 示例）：`deb2025/Dog_Skin_Disease_Recognition`
# 3. **猫狗皮肤病检测**（CNN + GNN）：`Myriam2907/FurSight_C`
# 4. **犬类皮肤真菌/细菌感染预测**：`Kaviyasri05/FURCAST_CARE_Animal-Skin-Disease-Prediction`
#
# 若需要更大规模、标注更完善的数据集，建议优先前往 **Kaggle** 或 **Roboflow Universe** 搜索。
