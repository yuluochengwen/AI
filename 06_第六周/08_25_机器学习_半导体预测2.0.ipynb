# %% [markdown]
# #### 导入必要的库

# %%
# 导入必要的库
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# 机器学习相关库
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# 设置中文字体
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# #### 读取数据集

# %%
train_df = pd.read_excel('data/final_data_1.xlsx')
test_df = pd.read_excel('data/test_features.xlsx')

# %%
train_df.head()
# Out:
#        ID TOOL   210X1  210X2  210X3  210X4  210X5  210X6  210X7  210X8  ...  \
# 0  NH0995    O  100.50  0.933   0.14  2.004  48.11  1.937  -0.54   1.13  ...
# 1  NH0996    O  100.50  0.583   0.14  1.752  48.00  1.572  -0.53   0.90  ...
# 2  NH0997    O  100.50  0.859   0.14  1.848  48.07  1.824  -0.70   0.58  ...
# 3  NH0998    O  100.45  1.639   0.14  2.021  48.03  2.331  -1.08   1.16  ...
# 4  NH0999    N   89.90  0.397   0.24  1.684  49.46  1.130   3.24  -0.76  ...
#
#    750X1441       750X1442  750X1444  750X1445  750X1447  750X1448  750X1450  \
# 0     209.8  2400000000000   0.00080   0.00080   0.00080   0.00080   0.00080
# 1     209.7  2400000000000   0.00081   0.00081   0.00081   0.00081   0.00081
# 2     209.8  2400000000000   0.00081   0.00081   0.00081   0.00081   0.00081
# 3     209.8  2400000000000   0.00081   0.00081   0.00081   0.00081   0.00081
# 4     213.3  2400000000000   0.00094   0.00094   0.00094   0.00094   0.00094
#
#    750X1451       750X1452     Value
# ...

# %%
test_df.head()
# Out:
#        ID TOOL   210X1  210X2  210X3  210X4  210X5  210X6  210X7  210X8  ...  \
# 0  NH1943    L  100.15  0.534   0.24  1.281  57.27  3.422  -2.08   0.39  ...
# 1  NH1944    N  102.05  0.488   0.26  1.972  68.01  4.576   3.78  -0.82  ...
# 2  NH1945    N  102.05  0.476   0.26  1.946  67.98  4.586   3.45  -0.84  ...
# 3  NH1946    J  101.10  0.354   0.40  0.854  71.15  3.736   0.04  -0.29  ...
# 4  NH1947    J  101.05  0.367   0.40  0.981  71.21  3.722  -0.06  -0.53  ...
#
#    750X1440  750X1441       750X1442  750X1444  750X1445  750X1447  750X1448  \
# 0       1.3     200.1  2400000000000   0.00069   0.00069   0.00069   0.00069
# 1       1.3     199.9  2400000000000   0.00063   0.00063   0.00063   0.00063
# 2       1.3     199.6  2400000000000   0.00070   0.00070   0.00070   0.00070
# 3       1.4     205.7  2400000000000   0.00066   0.00066   0.00066   0.00066
# 4       1.4     205.8  2400000000000   0.00072   0.00072   0.00072   0.00072
#
#    750X1450  750X1451       750X1452
# ...

# %% [markdown]
# #### 提取测试集和训练集的ID并保存
# 1. 或可用于后续分离测试集和训练集

# %%
train_df_ids = train_df[['ID']]
test_df_ids = test_df[['ID']]

# %% [markdown]
# #### 提取训练集的目标列

# %%
train_df_target = train_df[['Value']]
train_df_target.head()
# Out:
#       Value
# 0  2.814025
# 1  2.782955
# 2  2.725973
# 3  2.794768
# 4  2.787539

# %% [markdown]
# #### 去除训练集里的目标列

# %%
columns = [col for col in train_df.columns if col not in ['Value']]
X_train = train_df[columns]
y_train = train_df['Value']
X_test = test_df[columns]
print(X_train.shape, y_train.shape, X_test.shape)
# Out:
# (800, 5953) (800,) (300, 5953)

# %% [markdown]
# #### 拼接数据集, 为数据预处理做准备

# %%
total_set = pd.concat([X_train, X_test], axis=0)
total_set.shape
# Out:
# (1100, 5953)

# %%
total_set
# Out:
#          ID TOOL   210X1  210X2  210X3  210X4  210X5  210X6  210X7  210X8  \
# 0    NH0995    O  100.50  0.933   0.14  2.004  48.11  1.937  -0.54   1.13
# 1    NH0996    O  100.50  0.583   0.14  1.752  48.00  1.572  -0.53   0.90
# 2    NH0997    O  100.50  0.859   0.14  1.848  48.07  1.824  -0.70   0.58
# 3    NH0998    O  100.45  1.639   0.14  2.021  48.03  2.331  -1.08   1.16
# 4    NH0999    N   89.90  0.397   0.24  1.684  49.46  1.130   3.24  -0.76
# ..      ...  ...     ...    ...    ...    ...    ...    ...    ...    ...
# 295  NH0459    N   90.13  0.384   0.25  1.494  49.55  1.144   3.42  -0.73
# 296  NH0460    O  100.70  0.593   0.14  1.938  48.86  1.715  -0.81   1.22
# 297  NH0461    N   90.13  0.376   0.25  1.321  49.48  1.079   3.82  -0.55
# 298  NH0462    O  100.70  0.585   0.14  1.941  48.97  1.712  -1.09   1.28
# 299  NH0463    N   90.12  0.376   0.25  1.495  49.57  1.138   3.95  -1.02
#
#      ...  750X1440  750X1441       750X1442  750X1444  750X1445  750X1447  \
# ...

# %% [markdown]
# #### 去除数据集里的ID列

# %%
total_set = total_set.drop(columns=['ID'])
total_set.head()
# Out:
#   TOOL   210X1  210X2  210X3  210X4  210X5  210X6  210X7  210X8  210X9  ...  \
# 0    O  100.50  0.933   0.14  2.004  48.11  1.937  -0.54   1.13   0.07  ...
# 1    O  100.50  0.583   0.14  1.752  48.00  1.572  -0.53   0.90   0.06  ...
# 2    O  100.50  0.859   0.14  1.848  48.07  1.824  -0.70   0.58   0.05  ...
# 3    O  100.45  1.639   0.14  2.021  48.03  2.331  -1.08   1.16   0.06  ...
# 4    N   89.90  0.397   0.24  1.684  49.46  1.130   3.24  -0.76  -0.13  ...
#
#    750X1440  750X1441       750X1442  750X1444  750X1445  750X1447  750X1448  \
# 0       1.5     209.8  2400000000000   0.00080   0.00080   0.00080   0.00080
# 1       1.5     209.7  2400000000000   0.00081   0.00081   0.00081   0.00081
# 2       1.5     209.8  2400000000000   0.00081   0.00081   0.00081   0.00081
# 3       1.5     209.8  2400000000000   0.00081   0.00081   0.00081   0.00081
# 4       1.5     213.3  2400000000000   0.00094   0.00094   0.00094   0.00094
#
#    750X1450  750X1451       750X1452
# ...

# %% [markdown]
# #### 查看空值

# %%
nan_cols = total_set.isnull().sum()
nan_cols = nan_cols[nan_cols > 500]
nan_cols.sort_values(ascending=False).head()
print(f'缺失值列数: {len(nan_cols)}')
# Out:
# 缺失值列数: 229

# %% [markdown]
# #### 删除缺失超过50%的特征列

# %%
total_set = total_set.drop(columns=nan_cols.index)

# %%
total_set.head()
# Out:
#   TOOL   210X1  210X2  210X3  210X4  210X5  210X6  210X7  210X8  210X9  ...  \
# 0    O  100.50  0.933   0.14  2.004  48.11  1.937  -0.54   1.13   0.07  ...
# 1    O  100.50  0.583   0.14  1.752  48.00  1.572  -0.53   0.90   0.06  ...
# 2    O  100.50  0.859   0.14  1.848  48.07  1.824  -0.70   0.58   0.05  ...
# 3    O  100.45  1.639   0.14  2.021  48.03  2.331  -1.08   1.16   0.06  ...
# 4    N   89.90  0.397   0.24  1.684  49.46  1.130   3.24  -0.76  -0.13  ...
#
#    750X1440  750X1441       750X1442  750X1444  750X1445  750X1447  750X1448  \
# 0       1.5     209.8  2400000000000   0.00080   0.00080   0.00080   0.00080
# 1       1.5     209.7  2400000000000   0.00081   0.00081   0.00081   0.00081
# 2       1.5     209.8  2400000000000   0.00081   0.00081   0.00081   0.00081
# 3       1.5     209.8  2400000000000   0.00081   0.00081   0.00081   0.00081
# 4       1.5     213.3  2400000000000   0.00094   0.00094   0.00094   0.00094
#
#    750X1450  750X1451       750X1452
# ...

# %% [markdown]
# #### 将数值列与非数值列分开

# %%
num_cols = total_set.select_dtypes(include=['int64', 'float64']).columns.tolist()
obj_cols = total_set.select_dtypes(include=['object']).columns.tolist()

# %%
print('数值列数量:',len(num_cols))
# Out:
# 数值列数量: 5712

# %%
print('类别列数量:',len(obj_cols))
# Out:
# 类别列数量: 11

# %%
total_set[num_cols].head()
# Out:
#     210X1  210X2  210X3  210X4  210X5  210X6  210X7  210X8  210X9  210X10  \
# 0  100.50  0.933   0.14  2.004  48.11  1.937  -0.54   1.13   0.07    24.6
# 1  100.50  0.583   0.14  1.752  48.00  1.572  -0.53   0.90   0.06    24.3
# 2  100.50  0.859   0.14  1.848  48.07  1.824  -0.70   0.58   0.05    24.8
# 3  100.45  1.639   0.14  2.021  48.03  2.331  -1.08   1.16   0.06    23.9
# 4   89.90  0.397   0.24  1.684  49.46  1.130   3.24  -0.76  -0.13    24.8
#
#    ...  750X1440  750X1441       750X1442  750X1444  750X1445  750X1447  \
# 0  ...       1.5     209.8  2400000000000   0.00080   0.00080   0.00080
# 1  ...       1.5     209.7  2400000000000   0.00081   0.00081   0.00081
# 2  ...       1.5     209.8  2400000000000   0.00081   0.00081   0.00081
# 3  ...       1.5     209.8  2400000000000   0.00081   0.00081   0.00081
# 4  ...       1.5     213.3  2400000000000   0.00094   0.00094   0.00094
#
#    750X1448  750X1450  750X1451       750X1452
# ...

# %% [markdown]
# #### 删除标准差为0的列

# %%
std_cols = total_set[num_cols].std()
