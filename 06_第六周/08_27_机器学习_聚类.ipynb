# %% [markdown]
# #### 聚类算法
# 1. 聚类算法是一种无监督学习方法，它将数据集中的对象分为若干个类别，使得同一类的对象之间具有较高的相似度，不同类的对象之间具有较低的相似度。聚类算法的目标是使得同一类的对象之间具有较高的相似度，不同类的对象之间具有较低的相似度。
# 2. 常见的聚类算法有：
#     - K-means 算法
#     - DBSCAN 算法
#     - 层次聚类算法
#     - 谱聚类算法
#     - 凝聚聚类算法
#     - 高斯混合模型算法
#     - 核密度聚类算法
#     - 基于密度的聚类算法
