# %% [markdown]
# # 调用本地大模型

# %%
import requests
def LLM(model_name, prompt):
    url = "http://localhost:11434/api/generate"
    data = {
        "model": model_name,
        "prompt": prompt,
        "stream": False
    }

    response = requests.post(url, json=data)
    if response.status_code == 200:
        result = response.json()
        return result['response']
    else:
        return f"Error: {response.status_code}"
    
# 示例调用
if __name__ == "__main__":
    model_name = "deepseek-r1:8b"
    prompt = "人工智能的未来发展方向有哪些？"
    response = LLM(model_name, prompt)
    print(response)
# Out:
# <think>
# 嗯，用户问的是人工智能的未来发展方向啊，这是个挺大的题目。首先想想用户可能是什么背景吧，可能是学生做研究者或者对AI感兴趣者，也可能是从业者，或者只是随便问问的普通人想了解未来趋势，得考虑到回复要全面但不能太技术化太专业也不能太浅显摆得水要平平衡。
#
# 先从宏观角度来分析吧核心趋势用户想知道发展点，从技术上人工智能有模型提升、应用、伦理、人机交互、产业影响等方面展开来组织结构。技术上分几大块写吧，比如模型发展、智能提升、人机理、通用AI、机器、人、交互、融合、脑科学、安全、产业、融合然后社会应用伦理这些方向。
#
# 技术细节方面深度学习模型发展有大模型能力提升，包括推理、多模态学习、自适应性、工具、解释等通用性这些通用AI是AGI路径有符号主义和连接主义派进化论AI机器人有具身融合人机脑科学等安全伦理社会影响就业伦理法规教育等等。
#
# 用户要提到要避免太具体技术术语，比如用例子解释说"涌现""涌现""意识"解释""机器意识""通用AI"概念""具身心灵""图灵性""脑机"这些但不能太复杂用但不用术语。
#
# 用户可能不懂得地方用比喻比如用"能理解学习""感觉""思考""智能身体""思考""感觉""感觉""智能"来"这样用户理解。
#
# 还要连贯性结构，从到未来趋势到具体例子比如医疗教育到安全要连到应用到社会影响最后结语总结展望要激励人。
#
# 用户思考别太绝对预测别太肯定AI说"必然这样未来""保证""一定""绝对"用可能""会"用可能""或许""趋势""也许"语气。
#
# 长度适中等下用户回复200000000字左右吧字合适。
# </think>
# </think>
# 人工智能的未来发展方向是一个充满无限广阔且充满可能的领域，它的发展方向，主要集中在以下几个关键领域值得关注：
#
# 1. **人工智能技术增强模型的深度发展**：**：
# *大模型将变得更强大、多模态(图像文本、音视理解、解、多任务)、推理、自、交互、适应、生成、解释、自主. 通用人工智能(AGI.
# 2人类与机器学习：通用AI人融合：物理世界人交互.
# * 身体智能人脑融合脑:人机.
# 安全与伦理与法规：保障
# 社会影响.
# AI教育与融合：教育.
#
# 未来AI将助人类生活工作方式变革智产业转型.
